# %%
import pandas as pd
import plotly.express as px
import chardet
with open ("data/taxationbydistrict.csv","rb") as f:
    print(chardet.detect(f.read()))

#There was an issue here with the letter script type -> eg it was not set in the latin alphabet UTC+8
#I converted it to the ISO-8859-1, since this is the only one that worked...
# Out:
# {'encoding': 'ISO-8859-1', 'confidence': 0.7202336764815975, 'language': ''}

# %%
income_tax_information = pd.read_csv("data/taxationbydistrict.csv", encoding="ISO-8859-1", sep=";")

# %%
income_tax_information.head()
# Out:
#                                                                                                                               Tabelle: 73111-01-01-5
# Lohn- und Einkommensteuerpflichtige, Gesamtbetr... NaN NaN NaN                                 NaN                                               NaN
# Einkünfte, Lohn- und Einkommensteuer - Jahressu... NaN NaN NaN                                 NaN                                               NaN
# regionale Tiefe: Gemeinden                         NaN NaN NaN                                 NaN                                               NaN
# Lohn- und Einkommensteuerstatistik                 NaN NaN NaN                                 NaN                                               NaN
# NaN                                                NaN NaN Lohn- und Einkommensteuerpflichtige Gesamtbetrag der Einkünfte  Lohn- und Einkommensteuer

# %%
income_tax_information.columns
# Out:
# Index(['Tabelle: 73111-01-01-5'], dtype='object')

# %%
income_tax_information.sample()
# Out:
#                             Tabelle: 73111-01-01-5
# 2021 15083425 Ovelgünne - -                      -

# %%
#Now to do everything with Pandas...
income_tax_information.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 13934 entries, ('Lohn- und Einkommensteuerpflichtige, Gesamtbetrag der', nan, nan, nan, nan) to ('Stand: 12.11.2025 / 13:43:35', nan, nan, nan, nan)
# Data columns (total 1 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Tabelle: 73111-01-01-5  13926 non-null  object
# dtypes: object(1)
# memory usage: 1.9+ MB

# %%
#I am getting too many errors due to the weird way this data is structured.

# %%
#Now I am going to create a raw data set that will allow me to interact with it nicer
import csv

print(income_tax_information)

with open ("data/taxationbydistrict.csv","r",encoding="ISO-8859-1", errors="replace") as f:
    for i in range(40):
        print(f.readline())


raw = pd.read_csv("data/taxationbydistrict.csv",
    sep=";",
    encoding="ISO-8859-1",
    header=None,
    engine= "python",
    quotechar='|',
    on_bad_lines='skip',
    skiprows=1,
    na_values=["-","."],
)

raw.all
# Out:
#                                                                                                                                              Tabelle: 73111-01-01-5
# Lohn- und Einkommensteuerpflichtige, Gesamtbetr... NaN      NaN           NaN                                 NaN                                               NaN
# Einkünfte, Lohn- und Einkommensteuer - Jahressu... NaN      NaN           NaN                                 NaN                                               NaN
# regionale Tiefe: Gemeinden                         NaN      NaN           NaN                                 NaN                                               NaN
# Lohn- und Einkommensteuerstatistik                 NaN      NaN           NaN                                 NaN                                               NaN
# NaN                                                NaN      NaN           Lohn- und Einkommensteuerpflichtige Gesamtbetrag der Einkünfte  Lohn- und Einkommensteuer
# ...

# %%
raw.info()
raw.head(50)
raw.tail(50)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13980 entries, 0 to 13979
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       13978 non-null  object
#  1   1       13924 non-null  object
#  2   2       13924 non-null  object
#  3   3       11087 non-null  object
#  4   4       11088 non-null  object
#  5   5       11086 non-null  object
# dtypes: object(6)
# memory usage: 655.4+ KB
#                                                        0     1     2     3  \
# 13930                                         __________  None  None  None
# 13931  "Der dargestellte Gebietsstand entspricht dem ...  None  None  None
# 13932  Ende des Veranlagungszeitraumes von bis zu 2 ¾...  None  None  None
# 13933  den Berichtszeitpunkt t liegt daher der Gebiet...  None  None  None
# 13934                                    Jahre zugrunde.  None  None  None
# ...

# %%
with open("/mnt/data/taxationbydistrict.csv", "r", encoding="ISO-8859-1", errors="replace") as f:
    for i in range(60):
        print(f.readline())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[88], line 1
# ----> 1 with open("/mnt/data/taxationbydistrict.csv", "r", encoding="ISO-8859-1", errors="replace") as f:
#       2     for i in range(60):
#       3         print(f.readline())
#
# File ~/anaconda3/envs/ashley_edgar_datascience_and_ai/lib/python3.13/site-packages/IPython/core/interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/data/taxationbydistrict.csv'
